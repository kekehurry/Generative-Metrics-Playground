# %%
#resident
# %101% Single family - 4
# %104% Two family - 8
# %105% Three family - 12
# %111% 4-8 units -24
# %112% >8 units  -40
# %121% Boarding house

#Commercial

#Office

# %%
#'Cemetery','Charitable/Religious','Government Operations',
#设施可用 -'Health','Higher Education','Education'，'Mixed Use Education'，'Privately-Owned Open Space'，'Public Open Space'，'Transportation'，Utilty
#空置 - 'Vacant Commercial'，'Vacant Industrial'，'Vacant Residential'

#resident
#'Assisted Living/Boarding House'
#'Education Residential'，'Residential'
#'Mixed Use Residential'

#Local business
#'Commercial'
#'Mixed Use Commercial'

#Industry group
#'Industrial'
#'Office'
#'Office/R&D'

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from pyproj import Transformer

try:
    apply = apply
except NameError:
    def apply(f,*args,**kw):
        return f(*args,**kw)

# %%
#读取数据
land_shp = '../data/CDD_LandUseKD.geojson'
building_shp = '../data/BASEMAP_BuildingsKD.geojson'
boundary_shp = '../data/kendallsquare.geojson'

#建筑与地块裁切
land_data = gpd.read_file(land_shp)
building_data = gpd.read_file(building_shp)
boundary_data =gpd.read_file(boundary_shp)
# building_data = building_data.rename(columns={'Shape_area': 'building_area'})

# 定义转换器，从 EPSG:4326 到 EPSG:3857
transformer = Transformer.from_crs("EPSG:4326","EPSG:3857", always_xy=True)
# 转换图层的坐标参考系统
building_data = building_data.to_crs("EPSG:3857")
# 计算多边形的面积，并转换为平方米
building_data['bu_area_sqm'] = building_data.geometry.area
building_data = building_data.to_crs("EPSG:4326")

land_data = land_data.to_crs("EPSG:3857")
land_data['ld_area_sqm'] = land_data.geometry.area
land_data = land_data.to_crs("EPSG:4326")


land_data.head()
# Out:
#        ML MAP  LOT         Location  LandArea LUCode           LUDesc  \
# 0   16-33  16   33     270 THIRD ST   17436.0    013     MULTIUSE-RES
# 1   47-85  47   85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 2  48-157  48  157      314 MAIN ST   43430.0    340       GEN-OFFICE
# 3    47-4  47    4      180 MAIN ST   30450.0    942  Private College
# 4   47-80  47   80   46 MEMORIAL DR  123273.0    942  Private College
#
#                 Category  ExistUnits MixedUseTy GQLodgingH GradStuden  \
# 0  Mixed Use Residential        91.0       None       None       None
# 1      Vacant Commercial         0.0       None       None       None
# 2                 Office         0.0       None       None       None
# 3       Higher Education         0.0       None       None       None
# 4       Higher Education         0.0       None       None       None
#
#   CondoFlag    TaxStatus     Shape_STAr   Shape_STLe  \
# 0      None         None   17011.857591   577.886930
# 1      None  Educ NonTax   33121.022346   774.777682
# 2      None         None   37986.329106   790.756105
# 3      None  Educ NonTax   30954.198756   749.281516
# 4      None  Educ NonTax  123168.068201  1899.484240
#
#                                             geometry
# 0  MULTIPOLYGON (((-71.08165 42.36627, -71.08188 ...
# 1  MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...
# 2  MULTIPOLYGON (((-71.08629 42.36186, -71.08647 ...
# 3  MULTIPOLYGON (((-71.08325 42.36196, -71.08335 ...
# 4  MULTIPOLYGON (((-71.08245 42.36190, -71.08252 ...

# %%
building_data.head()
# building_data.plot(markersize=.5);
# Out:
#            TYPE  BASE_ELEV  ELEV_SL  TOP_SL  ELEV_GL  TOP_GL    BldgID  \
# 0  OVHD-WALKWAY        9.2     50.3    53.3     41.1    44.1  999-3381
# 1  OVHD-WALKWAY        9.3     54.5    54.5     45.2    45.2  999-3384
# 2  OVHD-WALKWAY        7.0    118.5   118.5    111.5   111.5  999-3386
# 3          BLDG        8.0     44.4    63.5     36.4    55.5     696-7
# 4          BLDG       10.7     26.8    28.0     16.1    17.3     696-6
#
#   EditDate  created_da  last_edite   Shape_area   Shape_len  \
# 0     None  2020-04-27  2021-10-20   700.714090  151.602427
# 1     None  2020-04-27  2021-10-20   582.257743  148.320478
# 2     None  2020-04-27  2021-10-20   178.217414   56.984752
# 3     None  2020-04-27  2020-04-27  7016.927026  482.230028
# 4     None  2020-04-27  2020-04-27   300.621583   73.340090
#
#                                             geometry     area_sqm
# 0  MULTIPOLYGON (((-71.08464 42.36090, -71.08467 ...    12.598554
# 1  MULTIPOLYGON (((-71.08412 42.36052, -71.08416 ...    30.406711
# 2  MULTIPOLYGON (((-71.08602 42.36012, -71.08605 ...    30.344750
# 3  MULTIPOLYGON (((-71.08679 42.35972, -71.08686 ...  1194.739239
# 4  MULTIPOLYGON (((-71.08684 42.35980, -71.08688 ...    51.185774

# %%
# 按地块和用地类型分组，并计算建筑面积总和
groupedLandBuilding_data = gpd.sjoin(land_data, building_data, op='intersects')

groupedLandBuilding_data['floor'] = np.floor(groupedLandBuilding_data['TOP_GL'] / 4.23)
#计算建筑面积
groupedLandBuilding_data['floor_area'] = groupedLandBuilding_data['floor'] * groupedLandBuilding_data['area_sqm']

groupedLandBuilding_data
# Out:
# /Users/majue/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3377: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
#          ML MAP  LOT         Location  LandArea LUCode           LUDesc  \
# 0     16-33  16   33     270 THIRD ST   17436.0    013     MULTIUSE-RES
# 1     47-85  47   85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 3      47-4  47    4      180 MAIN ST   30450.0    942  Private College
# 1     47-85  47   85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 2    48-157  48  157      314 MAIN ST   43430.0    340       GEN-OFFICE
# ..      ...  ..  ...              ...       ...    ...              ...
# 167  44-104  44  104   80-90 Broadway   41170.0    346       INV-OFFICE
# 168  44-105  44  105   355 Man Street   48814.0    346       INV-OFFICE
# 167  44-104  44  104   80-90 Broadway   41170.0    346       INV-OFFICE
# 168  44-105  44  105   355 Man Street   48814.0    346       INV-OFFICE
# 168  44-105  44  105   355 Man Street   48814.0    346       INV-OFFICE
#
#                   Category  ExistUnits MixedUseTy  ... TOP_GL    BldgID  \
# 0    Mixed Use Residential        91.0       None  ...  112.9     590-1
# 1        Vacant Commercial         0.0       None  ...  276.4     680-2
# 3         Higher Education         0.0       None  ...  276.4     680-2
# 1        Vacant Commercial         0.0       None  ...    0.0     680-1
# 2                   Office         0.0       None  ...    0.0     674-1
# ..                     ...         ...        ...  ...    ...       ...
# 167                 Office         0.0       None  ...  202.2     643-7
# 168                 Office         0.0       None  ...  202.2     643-7
# 167                 Office         0.0       None  ...  192.9     643-1
# 168                 Office         0.0       None  ...   83.3  999-5039
# 168                 Office         0.0       None  ...  184.3     643-4
#
#     EditDate  created_da  last_edite    Shape_area   Shape_len     area_sqm  \
# 0       None  2020-04-27  2020-04-27  11541.043784  509.419745  1965.436314
# 1       None  2020-04-27  2020-04-27   5799.000746  304.637630   987.434750
# 3       None  2020-04-27  2020-04-27   5799.000746  304.637630   987.434750
# 1       2021  2021-02-10  2021-02-10    192.117137   56.316862    32.713396
# 2       2020  2020-04-27  2020-04-27  30064.518560  696.834530  5119.350709
# ..       ...         ...         ...           ...         ...          ...
# 167     None  2021-04-07  2021-04-07  16453.843928  568.948509  2801.841079
# 168     None  2021-04-07  2021-04-07  16453.843928  568.948509  2801.841079
# 167     None  2020-04-27  2020-04-27  20253.308569  636.521188  3448.859441
# 168     None  2020-04-27  2021-10-20    265.397494   67.560990    40.612645
# 168     None  2020-04-27  2020-04-27  25452.222647  691.073286  4314.690035
#
#     floor     floor_area
# 0    26.0   51101.344168
# 1    65.0   64183.258782
# 3    65.0   64183.258782
# 1     0.0       0.000000
# 2     0.0       0.000000
# ..    ...            ...
# 167  47.0  131686.530720
# 168  47.0  131686.530720
# 167  45.0  155198.674857
# 168  19.0     771.640248
# 168  43.0  185531.671500
#
# [331 rows x 33 columns]

# %%
groupedLandBuilding_data.columns
# Out:
# Index(['ML', 'MAP', 'LOT', 'Location', 'LandArea', 'LUCode', 'LUDesc',
#        'Category', 'ExistUnits', 'MixedUseTy', 'GQLodgingH', 'GradStuden',
#        'CondoFlag', 'TaxStatus', 'Shape_STAr', 'Shape_STLe', 'geometry',
#        'index_right', 'TYPE', 'BASE_ELEV', 'ELEV_SL', 'TOP_SL', 'ELEV_GL',
#        'TOP_GL', 'BldgID', 'EditDate', 'created_da', 'last_edite',
#        'Shape_area', 'Shape_len', 'area_sqm', 'floor_area'],
#       dtype='object')

# %%
columns = ['ML','Location','LandArea','LUCode','LUDesc','Category','ExistUnits','TYPE','BldgID','floor_area','geometry']
land_building = groupedLandBuilding_data[columns]

# %%
land_building
# Out:
#          ML         Location  LandArea LUCode           LUDesc  \
# 0     16-33     270 THIRD ST   17436.0    013     MULTIUSE-RES
# 1     47-85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 3      47-4      180 MAIN ST   30450.0    942  Private College
# 1     47-85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 2    48-157      314 MAIN ST   43430.0    340       GEN-OFFICE
# ..      ...              ...       ...    ...              ...
# 167  44-104   80-90 Broadway   41170.0    346       INV-OFFICE
# 168  44-105   355 Man Street   48814.0    346       INV-OFFICE
# 167  44-104   80-90 Broadway   41170.0    346       INV-OFFICE
# 168  44-105   355 Man Street   48814.0    346       INV-OFFICE
# 168  44-105   355 Man Street   48814.0    346       INV-OFFICE
#
#                   Category  ExistUnits          TYPE    BldgID     floor_area  \
# 0    Mixed Use Residential        91.0          BLDG     590-1   73965.919956
# 1        Vacant Commercial         0.0          BLDG     680-2   90975.655011
# 3         Higher Education         0.0          BLDG     680-2   90975.655011
# 1        Vacant Commercial         0.0          BLDG     680-1       0.000000
# 2                   Office         0.0    FOUNDATION     674-1       0.000000
# ..                     ...         ...           ...       ...            ...
# 167                 Office         0.0          BLDG     643-7  188844.088735
# 168                 Office         0.0          BLDG     643-7  188844.088735
# 167                 Office         0.0          BLDG     643-1  221761.662074
# 168                 Office         0.0  OVHD-WALKWAY  999-5039    1127.677766
# 168                 Office         0.0          BLDG     643-4  265065.791143
#
#                                               geometry
# 0    MULTIPOLYGON (((-71.08165 42.36627, -71.08188 ...
# 1    MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...
# 3    MULTIPOLYGON (((-71.08325 42.36196, -71.08335 ...
# 1    MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...
# 2    MULTIPOLYGON (((-71.08629 42.36186, -71.08647 ...
# ..                                                 ...
# 167  MULTIPOLYGON (((-71.08652 42.36344, -71.08653 ...
# 168  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...
# 167  MULTIPOLYGON (((-71.08652 42.36344, -71.08653 ...
# 168  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...
# 168  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...
#
# [331 rows x 11 columns]

# %%
land_building.plot(markersize=.5);
# Out:
# /Users/majue/opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:51: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:

# %% [markdown]
# # 包含地理位置信息的角色

# %%
land_building.Category.value_counts()
# Out:
# Office                        73
# Office/R&D                    47
# Utility                       44
# Residential                   35
# Higher Education              27
# Transportation                19
# Commercial                    18
# Government Operations         17
# Mixed Use Residential         12
# Industrial                    11
# Vacant Commercial              8
# Privately-Owned Open Space     8
# Education Residential          5
# Public Open Space              4
# Charitable/Religious           2
# Mixed Use Commercial           1
# Name: Category, dtype: int64

# %%
LB_data = land_building.copy()
LB_data.loc[LB_data['Category'].isin(['Commercial', 'Mixed Use Commercial', 'Privately-Owned Open Space']), 'stakeholder'] = 'LBO'
LB_data.loc[LB_data['Category'].isin(['Industrial', 'Office', 'Office/R&D']), 'stakeholder'] = 'IG'
LB_data.loc[LB_data['Category'].isin(['Assisted Living/Boarding House', 'Education Residential', 'Residential', 'Mixed Use Residential']), 'stakeholder'] = 'RS'
LB_data.loc[LB_data['Category'].isin(['Utility', 'Transportation', 'Government Operations', 'Public Open Space']), 'stakeholder'] = 'GOV'
LB_data.loc[LB_data['Category'].isin(['Charitable/Religious', 'Higher Education']), 'stakeholder'] = 'NPI'
LB_data.loc[LB_data['Category'].isin(['Vacant Commercial']), 'stakeholder'] = 'DEV'
LB_data.loc[LB_data['ML'].isin(['29-50']), 'stakeholder'] = 'DEV'
LB_data
# Out:
#          ML         Location  LandArea LUCode           LUDesc  \
# 0     16-33     270 THIRD ST   17436.0    013     MULTIUSE-RES
# 1     47-85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 3      47-4      180 MAIN ST   30450.0    942  Private College
# 1     47-85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 2    48-157      314 MAIN ST   43430.0    340       GEN-OFFICE
# ..      ...              ...       ...    ...              ...
# 167  44-104   80-90 Broadway   41170.0    346       INV-OFFICE
# 168  44-105   355 Man Street   48814.0    346       INV-OFFICE
# 167  44-104   80-90 Broadway   41170.0    346       INV-OFFICE
# 168  44-105   355 Man Street   48814.0    346       INV-OFFICE
# 168  44-105   355 Man Street   48814.0    346       INV-OFFICE
#
#                   Category  ExistUnits          TYPE    BldgID     floor_area  \
# 0    Mixed Use Residential        91.0          BLDG     590-1   73965.919956
# 1        Vacant Commercial         0.0          BLDG     680-2   90975.655011
# 3         Higher Education         0.0          BLDG     680-2   90975.655011
# 1        Vacant Commercial         0.0          BLDG     680-1       0.000000
# 2                   Office         0.0    FOUNDATION     674-1       0.000000
# ..                     ...         ...           ...       ...            ...
# 167                 Office         0.0          BLDG     643-7  188844.088735
# 168                 Office         0.0          BLDG     643-7  188844.088735
# 167                 Office         0.0          BLDG     643-1  221761.662074
# 168                 Office         0.0  OVHD-WALKWAY  999-5039    1127.677766
# 168                 Office         0.0          BLDG     643-4  265065.791143
#
#                                               geometry stakeholder
# 0    MULTIPOLYGON (((-71.08165 42.36627, -71.08188 ...          RS
# 1    MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...         DEV
# 3    MULTIPOLYGON (((-71.08325 42.36196, -71.08335 ...         NPI
# 1    MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...         DEV
# 2    MULTIPOLYGON (((-71.08629 42.36186, -71.08647 ...          IG
# ..                                                 ...         ...
# 167  MULTIPOLYGON (((-71.08652 42.36344, -71.08653 ...          IG
# 168  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...          IG
# 167  MULTIPOLYGON (((-71.08652 42.36344, -71.08653 ...          IG
# 168  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...          IG
# 168  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...          IG
#
# [331 rows x 12 columns]

# %%
# 重新设置索引，去除重复的标签
LB_data = LB_data.reset_index(drop=True)
# get stakeholder pop_num from building area per capita
LB_data['pop_num'] = 0
LB_data.loc[LB_data['stakeholder'].isin(['LBO']), 'pop_num'] = LB_data['floor_area'] / 40  # workforce 40 sqft/person
LB_data.loc[LB_data['stakeholder'].isin(['IG']), 'pop_num'] = LB_data['floor_area'] / 200 # workforce 200 sqft/person
LB_data.loc[LB_data['stakeholder'].isin(['RS']), 'pop_num'] = LB_data['floor_area'] / 50 # resident 50 sqft/person  US average

# %%
LB_data
# Out:
#          ML         Location  LandArea LUCode           LUDesc  \
# 0     16-33     270 THIRD ST   17436.0    013     MULTIUSE-RES
# 1     47-85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 2      47-4      180 MAIN ST   30450.0    942  Private College
# 3     47-85  84 WADSWORTH ST   33621.0    390     COM-DEV-LAND
# 4    48-157      314 MAIN ST   43430.0    340       GEN-OFFICE
# ..      ...              ...       ...    ...              ...
# 326  44-104   80-90 Broadway   41170.0    346       INV-OFFICE
# 327  44-105   355 Man Street   48814.0    346       INV-OFFICE
# 328  44-104   80-90 Broadway   41170.0    346       INV-OFFICE
# 329  44-105   355 Man Street   48814.0    346       INV-OFFICE
# 330  44-105   355 Man Street   48814.0    346       INV-OFFICE
#
#                   Category  ExistUnits          TYPE    BldgID     floor_area  \
# 0    Mixed Use Residential        91.0          BLDG     590-1   73965.919956
# 1        Vacant Commercial         0.0          BLDG     680-2   90975.655011
# 2         Higher Education         0.0          BLDG     680-2   90975.655011
# 3        Vacant Commercial         0.0          BLDG     680-1       0.000000
# 4                   Office         0.0    FOUNDATION     674-1       0.000000
# ..                     ...         ...           ...       ...            ...
# 326                 Office         0.0          BLDG     643-7  188844.088735
# 327                 Office         0.0          BLDG     643-7  188844.088735
# 328                 Office         0.0          BLDG     643-1  221761.662074
# 329                 Office         0.0  OVHD-WALKWAY  999-5039    1127.677766
# 330                 Office         0.0          BLDG     643-4  265065.791143
#
#                                               geometry stakeholder  \
# 0    MULTIPOLYGON (((-71.08165 42.36627, -71.08188 ...          RS
# 1    MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...         DEV
# 2    MULTIPOLYGON (((-71.08325 42.36196, -71.08335 ...         NPI
# 3    MULTIPOLYGON (((-71.08371 42.36202, -71.08374 ...         DEV
# 4    MULTIPOLYGON (((-71.08629 42.36186, -71.08647 ...          IG
# ..                                                 ...         ...
# 326  MULTIPOLYGON (((-71.08652 42.36344, -71.08653 ...          IG
# 327  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...          IG
# 328  MULTIPOLYGON (((-71.08652 42.36344, -71.08653 ...          IG
# 329  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...          IG
# 330  MULTIPOLYGON (((-71.08747 42.36319, -71.08743 ...          IG
#
#          pop_num
# 0    1479.318399
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ..           ...
# 326   944.220444
# 327   944.220444
# 328  1108.808310
# 329     5.638389
# 330  1325.328956
#
# [331 rows x 13 columns]

# %%
LB_data[LB_data['stakeholder']=='RS']
# Out:
#           ML            Location  LandArea LUCode                     LUDesc  \
# 0      16-33        270 THIRD ST   17436.0    013               MULTIUSE-RES
# 17     27-84        106 SIXTH ST    1342.0    101               SNGL-FAM-RES
# 18     27-83        104 SIXTH ST    2658.0    101               SNGL-FAM-RES
# 35      27-1        102 SIXTH ST    2000.0    104                TWO-FAM-RES
# 36      27-2      240 CHARLES ST    1200.0    104                TWO-FAM-RES
# 37      27-3      238 CHARLES ST     800.0    101               SNGL-FAM-RES
# 40     42-18        220 BROADWAY    1250.0    101               SNGL-FAM-RES
# 41     42-19        218 BROADWAY    1500.0    101               SNGL-FAM-RES
# 42     42-18        220 BROADWAY    1250.0    101               SNGL-FAM-RES
# 55     27-35        235 THIRD ST    2911.0    101               SNGL-FAM-RES
# 59     27-25      126 CHARLES ST    5000.0    111               4-8-UNIT-APT
# 61      27-6     225-243 BENT ST   20000.0    112                >8-UNIT-APT
# 67     17-76        202 THIRD ST    1702.0   0101            MXD SNGL-FAM-RE
# 78     27-35        235 THIRD ST    2911.0    101               SNGL-FAM-RES
# 87      16-6        159 FIRST ST   30000.0    112                >8-UNIT-APT
# 89      16-6        159 FIRST ST   30000.0    112                >8-UNIT-APT
# 90      16-6        159 FIRST ST   30000.0    112                >8-UNIT-APT
# 97     42-23      5 DICKINSON ST    1988.0    101               SNGL-FAM-RES
# 100    42-21         97 MOORE ST    1741.0    105               THREE-FM-RES
# 101    42-22      93-95 MOORE ST    1210.0    105               THREE-FM-RES
# 102    42-21         97 MOORE ST    1741.0    105               THREE-FM-RES
# 114    28-33        265 THIRD ST  109330.0    112                >8-UNIT-APT
# 120    16-34        50 ROGERS ST   35006.0    112                >8-UNIT-APT
# 167    14-59         165 Main St   41836.0   0112            MXD >8-UNIT-APT
# 173    14-59         165 Main St   41836.0   0112            MXD >8-UNIT-APT
# 175   48-159         292 MAIN ST  121625.0   9421  Private College Res Units
# 176   48-159         292 MAIN ST  121625.0   9421  Private College Res Units
# 181   48-154     100 MEMORIAL DR  103732.0    112                >8-UNIT-APT
# 184   48-154     100 MEMORIAL DR  103732.0    112                >8-UNIT-APT
# 185   48-154     100 MEMORIAL DR  103732.0    112                >8-UNIT-APT
# 186   52A-19     111 MEMORIAL DR   63407.0   9421  Private College Res Units
# 187   52A-19     111 MEMORIAL DR   63407.0   9421  Private College Res Units
# 188   52A-19     111 MEMORIAL DR   63407.0   9421  Private College Res Units
# 211  14-1038        350 THIRD ST   48106.0   0112            MXD >8-UNIT-APT
# 212  14-1038        350 THIRD ST   48106.0   0112            MXD >8-UNIT-APT
# 214  14-1038        350 THIRD ST   48106.0   0112            MXD >8-UNIT-APT
# 237    42-14        209 BROADWAY    4485.0    111               4-8-UNIT-APT
# 238    42-14        209 BROADWAY    4485.0    111               4-8-UNIT-APT
# 239    42-95        214 BROADWAY    1300.0    105               THREE-FM-RES
# 243    28-33        265 THIRD ST  109330.0    112                >8-UNIT-APT
# 244    28-33        265 THIRD ST  109330.0    112                >8-UNIT-APT
# 245    28-33        265 THIRD ST  109330.0    112                >8-UNIT-APT
# 246    28-33        265 THIRD ST  109330.0    112                >8-UNIT-APT
# 263    42-88  125-127 HARVARD ST   10286.0    112                >8-UNIT-APT
# 265    42-88  125-127 HARVARD ST   10286.0    112                >8-UNIT-APT
# 285    29-34        303 THIRD ST  143460.0   0112            MXD >8-UNIT-APT
# 286    29-34        303 THIRD ST  143460.0   0112            MXD >8-UNIT-APT
# 287    29-34        303 THIRD ST  143460.0   0112            MXD >8-UNIT-APT
# 288    29-34        303 THIRD ST  143460.0   0112            MXD >8-UNIT-APT
# 308    27-97        249 THIRD ST   26918.0    112                >8-UNIT-APT
# 324    16-35        161 FIRST ST   14921.0    013               MULTIUSE-RES
# 325   44-107          88 AMES ST   14743.0    112                >8-UNIT-APT
#
#                   Category  ExistUnits          TYPE    BldgID     floor_area  \
# 0    Mixed Use Residential        91.0          BLDG     590-1   73965.919956
# 17             Residential         1.0          BLDG     543-2    2368.459897
# 18             Residential         1.0          BLDG     543-2    2368.459897
# 35             Residential         2.0          BLDG     543-3    1906.355882
# 36             Residential         2.0          BLDG     543-4    1127.551570
# 37             Residential         1.0          BLDG     543-5     971.905846
# 40             Residential         1.0          BLDG     586-8    1507.623856
# 41             Residential         1.0          BLDG     586-8    1507.623856
# 42             Residential         1.0          BLDG     586-7    1407.554884
# 55             Residential         1.0       OUTBLDG  999-3933     209.705747
# 59             Residential         8.0          BLDG    549-20     127.740008
# 61             Residential        10.0          BLDG    543-17   19274.147472
# 67   Mixed Use Residential         1.0          BLDG     559-1       2.686269
# 78             Residential         1.0          BLDG    549-23    1102.906669
# 87             Residential       115.0          BLDG     582-4   28536.407879
# 89             Residential       115.0          BLDG     582-1   89269.520503
# 90             Residential       115.0          BLDG     582-2   11764.097347
# 97             Residential         1.0          BLDG    586-11    1173.346026
# 100            Residential         3.0          BLDG     586-3    2100.599604
# 101            Residential         3.0          BLDG     586-3    2100.599604
# 102            Residential         3.0          BLDG     586-1    1933.209269
# 114            Residential       186.0          BLDG     585-1   18897.255345
# 120            Residential       136.0     CONSTRUCT     600-3       0.000000
# 167  Mixed Use Residential       300.0          BLDG    620-80   45517.395587
# 173  Mixed Use Residential       300.0          BLDG    620-10       0.000000
# 175  Education Residential       454.0          BLDG    674-10       0.000000
# 176  Education Residential       454.0          BLDG     674-5       0.000000
# 181            Residential       263.0          BLDG     696-4  138371.221484
# 184            Residential       263.0          BLDG  999-3422   41805.253434
# 185            Residential       263.0  OVHD-WALKWAY  999-3386    1127.813218
# 186  Education Residential         6.0          BLDG     696-7   22102.675921
# 187  Education Residential         6.0          BLDG     696-6     295.171298
# 188  Education Residential         6.0          BLDG     696-5   53571.425266
# 211  Mixed Use Residential       465.0          BLDG    620-82  263031.627327
# 212  Mixed Use Residential       465.0          BLDG    620-89  117062.918050
# 214  Mixed Use Residential       465.0          BLDG    620-83  265284.163175
# 237            Residential         5.0          BLDG     561-5    3705.890718
# 238            Residential         5.0          BLDG     561-6    3976.692631
# 239            Residential         3.0          BLDG    586-10    2442.476205
# 243            Residential       186.0  OVHD-WALKWAY  999-4300     142.377914
# 244            Residential       186.0  OVHD-WALKWAY  999-3830     465.968491
# 245            Residential       186.0          BLDG     585-2  380081.677082
# 246            Residential       186.0        MOBILE  999-4101     391.517665
# 263            Residential        24.0          BLDG     593-2   50232.810408
# 265            Residential        24.0          BLDG     593-5    7320.425796
# 285  Mixed Use Residential       492.0          BLDG     614-7  214203.252372
# 286  Mixed Use Residential       492.0       OUTBLDG  999-3873      95.400906
# 287  Mixed Use Residential       492.0       OUTBLDG  999-3874     139.092381
# 288  Mixed Use Residential       492.0          BLDG     614-8  265086.522661
# 308            Residential        84.0          BLDG     569-1       0.000000
# 324  Mixed Use Residential        98.0          BLDG     600-1   32381.841284
# 325            Residential       280.0          BLDG     643-7  188844.088735
#
#                                               geometry stakeholder  \
# 0    MULTIPOLYGON (((-71.08165 42.36627, -71.08188 ...          RS
# 17   MULTIPOLYGON (((-71.08532 42.36791, -71.08556 ...          RS
# 18   MULTIPOLYGON (((-71.08536 42.36803, -71.08525 ...          RS
# 35   MULTIPOLYGON (((-71.08534 42.36814, -71.08535 ...          RS
# 36   MULTIPOLYGON (((-71.08522 42.36812, -71.08525 ...          RS
# 37   MULTIPOLYGON (((-71.08517 42.36800, -71.08525 ...          RS
# 40   MULTIPOLYGON (((-71.09386 42.36639, -71.09395 ...          RS
# 41   MULTIPOLYGON (((-71.09376 42.36635, -71.09385 ...          RS
# 42   MULTIPOLYGON (((-71.09386 42.36639, -71.09395 ...          RS
# 55   MULTIPOLYGON (((-71.08164 42.36721, -71.08165 ...          RS
# 59   MULTIPOLYGON (((-71.08193 42.36743, -71.08193 ...          RS
# 61   MULTIPOLYGON (((-71.08411 42.36770, -71.08413 ...          RS
# 67   MULTIPOLYGON (((-71.08093 42.36745, -71.08093 ...          RS
# 78   MULTIPOLYGON (((-71.08164 42.36721, -71.08165 ...          RS
# 87   MULTIPOLYGON (((-71.07836 42.36655, -71.07843 ...          RS
# 89   MULTIPOLYGON (((-71.07836 42.36655, -71.07843 ...          RS
# 90   MULTIPOLYGON (((-71.07836 42.36655, -71.07843 ...          RS
# 97   MULTIPOLYGON (((-71.09395 42.36627, -71.09389 ...          RS
# 100  MULTIPOLYGON (((-71.09385 42.36623, -71.09379 ...          RS
# 101  MULTIPOLYGON (((-71.09376 42.36611, -71.09380 ...          RS
# 102  MULTIPOLYGON (((-71.09385 42.36623, -71.09379 ...          RS
# 114  MULTIPOLYGON (((-71.08234 42.36602, -71.08273 ...          RS
# 120  MULTIPOLYGON (((-71.07842 42.36586, -71.07854 ...          RS
# 167  MULTIPOLYGON (((-71.08250 42.36251, -71.08254 ...          RS
# 173  MULTIPOLYGON (((-71.08250 42.36251, -71.08254 ...          RS
# 175  MULTIPOLYGON (((-71.08590 42.36068, -71.08622 ...          RS
# 176  MULTIPOLYGON (((-71.08590 42.36068, -71.08622 ...          RS
# 181  MULTIPOLYGON (((-71.08487 42.36011, -71.08493 ...          RS
# 184  MULTIPOLYGON (((-71.08487 42.36011, -71.08493 ...          RS
# 185  MULTIPOLYGON (((-71.08487 42.36011, -71.08493 ...          RS
# 186  MULTIPOLYGON (((-71.08630 42.35963, -71.08651 ...          RS
# 187  MULTIPOLYGON (((-71.08630 42.35963, -71.08651 ...          RS
# 188  MULTIPOLYGON (((-71.08630 42.35963, -71.08651 ...          RS
# 211  MULTIPOLYGON (((-71.08217 42.36356, -71.08234 ...          RS
# 212  MULTIPOLYGON (((-71.08217 42.36356, -71.08234 ...          RS
# 214  MULTIPOLYGON (((-71.08217 42.36356, -71.08234 ...          RS
# 237  MULTIPOLYGON (((-71.09364 42.36651, -71.09364 ...          RS
# 238  MULTIPOLYGON (((-71.09364 42.36651, -71.09364 ...          RS
# 239  MULTIPOLYGON (((-71.09371 42.36617, -71.09377 ...          RS
# 243  MULTIPOLYGON (((-71.08234 42.36602, -71.08273 ...          RS
# 244  MULTIPOLYGON (((-71.08234 42.36602, -71.08273 ...          RS
# 245  MULTIPOLYGON (((-71.08234 42.36602, -71.08273 ...          RS
# 246  MULTIPOLYGON (((-71.08234 42.36602, -71.08273 ...          RS
# 263  MULTIPOLYGON (((-71.09303 42.36559, -71.09312 ...          RS
# 265  MULTIPOLYGON (((-71.09303 42.36559, -71.09312 ...          RS
# 285  MULTIPOLYGON (((-71.08350 42.36398, -71.08352 ...          RS
# 286  MULTIPOLYGON (((-71.08350 42.36398, -71.08352 ...          RS
# 287  MULTIPOLYGON (((-71.08350 42.36398, -71.08352 ...          RS
# 288  MULTIPOLYGON (((-71.08350 42.36398, -71.08352 ...          RS
# 308  MULTIPOLYGON (((-71.08245 42.36646, -71.08245 ...          RS
# 324  MULTIPOLYGON (((-71.07854 42.36532, -71.07842 ...          RS
# 325  MULTIPOLYGON (((-71.08747 42.36319, -71.08747 ...          RS
#
#          pop_num
# 0    1479.318399
# 17     47.369198
# 18     47.369198
# 35     38.127118
# 36     22.551031
# 37     19.438117
# 40     30.152477
# 41     30.152477
# 42     28.151098
# 55      4.194115
# 59      2.554800
# 61    385.482949
# 67      0.053725
# 78     22.058133
# 87    570.728158
# 89   1785.390410
# 90    235.281947
# 97     23.466921
# 100    42.011992
# 101    42.011992
# 102    38.664185
# 114   377.945107
# 120     0.000000
# 167   910.347912
# 173     0.000000
# 175     0.000000
# 176     0.000000
# 181  2767.424430
# 184   836.105069
# 185    22.556264
# 186   442.053518
# 187     5.903426
# 188  1071.428505
# 211  5260.632547
# 212  2341.258361
# 214  5305.683264
# 237    74.117814
# 238    79.533853
# 239    48.849524
# 243     2.847558
# 244     9.319370
# 245  7601.633542
# 246     7.830353
# 263  1004.656208
# 265   146.408516
# 285  4284.065047
# 286     1.908018
# 287     2.781848
# 288  5301.730453
# 308     0.000000
# 324   647.636826
# 325  3776.881775

# %%
bgrp = gpd.read_file('/Users/majue/Documents/MIT/multi_stakeholders_indicator_d3-1/backend/data/bgrp_cambridge.geojson')
bgrp
# Out:
#               id label                              name  \
# 0   250173546002  bgrp     2 (Tract 3546, Middlesex, MA)
# 1   250173533001  bgrp     1 (Tract 3533, Middlesex, MA)
# 2   250173550001  bgrp     1 (Tract 3550, Middlesex, MA)
# 3   250173536005  bgrp     5 (Tract 3536, Middlesex, MA)
# 4   250173544002  bgrp     2 (Tract 3544, Middlesex, MA)
# ..           ...   ...                               ...
# 83  250173526001  bgrp     1 (Tract 3526, Middlesex, MA)
# 84  250173530001  bgrp     1 (Tract 3530, Middlesex, MA)
# 85  250173521021  bgrp  1 (Tract 3521.02, Middlesex, MA)
# 86  250173540002  bgrp     2 (Tract 3540, Middlesex, MA)
# 87  250173524001  bgrp     1 (Tract 3524, Middlesex, MA)
#
#                                              geometry
# 0   POLYGON ((-71.13286 42.38328, -71.13195 42.382...
# 1   POLYGON ((-71.10574 42.36182, -71.10556 42.361...
# 2   POLYGON ((-71.14066 42.39884, -71.14068 42.398...
# 3   POLYGON ((-71.11954 42.37631, -71.11948 42.376...
# 4   POLYGON ((-71.13697 42.38295, -71.13707 42.382...
# ..                                                ...
# 83  POLYGON ((-71.09013 42.37158, -71.09066 42.370...
# 84  POLYGON ((-71.10541 42.36641, -71.10570 42.366...
# 85  POLYGON ((-71.07157 42.36723, -71.07145 42.367...
# 86  POLYGON ((-71.12407 42.38421, -71.12414 42.384...
# 87  POLYGON ((-71.09180 42.36632, -71.09124 42.365...
#
# [88 rows x 4 columns]

# %%
bgrp.plot()
# Out:
# <AxesSubplot:>

# %%
pop = pd.read_csv('/Users/majue/Documents/MIT/Volpe/replica-test-04_20_23-population_dataset/replica-test-04_20_23-population_dataset.csv')
pop.head()
# Out:
#              person_id          household_id  age     sex  \
# 0  1080575451255828058   8708936110889382119   95    male
# 1  5457193592064276016  16502544353640454243   95    male
# 2  9418719122398331740  10796612515708179086   95    male
# 3  6520902190318608247  14808926745157455874   83  female
# 4  8955996023108459098   4932802100107204973   83  female
#
#                  race_ethnicity   employment_status  \
# 0  black_not_hispanic_or_latino  not_in_labor_force
# 1  black_not_hispanic_or_latino  not_in_labor_force
# 2  black_not_hispanic_or_latino  not_in_labor_force
# 3  black_not_hispanic_or_latino  not_in_labor_force
# 4  black_not_hispanic_or_latino  not_in_labor_force
#
#                                       wfh  individual_income  \
# 0  unemployed_under_16_not_in_labor_force              11432
# 1  unemployed_under_16_not_in_labor_force              11432
# 2  unemployed_under_16_not_in_labor_force              11432
# 3  unemployed_under_16_not_in_labor_force              14773
# 4  unemployed_under_16_not_in_labor_force              14773
#
#         commute_mode  household_size  ...  available_vehicles resident_type  \
# 0  other_travel_mode               1  ...                 one          core
# 1  other_travel_mode               1  ...                 one          core
# 2  other_travel_mode               1  ...                 one          core
# 3  other_travel_mode               1  ...                 one          core
# 4  other_travel_mode               1  ...                 one          core
#
#                        home_bgrp             home_trct              home_cty  \
# 0  2 (Tract 3538, Middlesex, MA)  3538 (Middlesex, MA)  Middlesex County, MA
# 1  2 (Tract 3523, Middlesex, MA)  3523 (Middlesex, MA)  Middlesex County, MA
# 2  3 (Tract 3532, Middlesex, MA)  3532 (Middlesex, MA)  Middlesex County, MA
# 3  3 (Tract 3543, Middlesex, MA)  3543 (Middlesex, MA)  Middlesex County, MA
# 4  1 (Tract 3537, Middlesex, MA)  3537 (Middlesex, MA)  Middlesex County, MA
#
#          home_st work_bgrp work_trct work_cty work_st
# 0  Massachusetts        \N        \N       \N      \N
# 1  Massachusetts        \N        \N       \N      \N
# 2  Massachusetts        \N        \N       \N      \N
# 3  Massachusetts        \N        \N       \N      \N
# 4  Massachusetts        \N        \N       \N      \N
#
# [5 rows x 21 columns]

# %%
# 统计人口数据，bgrp level
# 根据 'home_trct' 分组并计算每个地块的人数
people_count = pop.groupby('home_bgrp').size().reset_index(name='count')
# 合并 'bgrp' DataFrame 和 'people_count' DataFrame，根据 'home_trct' 进行匹配
merged_data = bgrp.merge(people_count, left_on='name', right_on='home_bgrp', how='left')

# 打印合并结果
merged_data
# Out:
#               id label                              name  \
# 0   250173546002  bgrp     2 (Tract 3546, Middlesex, MA)
# 1   250173533001  bgrp     1 (Tract 3533, Middlesex, MA)
# 2   250173550001  bgrp     1 (Tract 3550, Middlesex, MA)
# 3   250173536005  bgrp     5 (Tract 3536, Middlesex, MA)
# 4   250173544002  bgrp     2 (Tract 3544, Middlesex, MA)
# ..           ...   ...                               ...
# 83  250173526001  bgrp     1 (Tract 3526, Middlesex, MA)
# 84  250173530001  bgrp     1 (Tract 3530, Middlesex, MA)
# 85  250173521021  bgrp  1 (Tract 3521.02, Middlesex, MA)
# 86  250173540002  bgrp     2 (Tract 3540, Middlesex, MA)
# 87  250173524001  bgrp     1 (Tract 3524, Middlesex, MA)
#
#                                              geometry  \
# 0   POLYGON ((-71.13286 42.38328, -71.13195 42.382...
# 1   POLYGON ((-71.10574 42.36182, -71.10556 42.361...
# 2   POLYGON ((-71.14066 42.39884, -71.14068 42.398...
# 3   POLYGON ((-71.11954 42.37631, -71.11948 42.376...
# 4   POLYGON ((-71.13697 42.38295, -71.13707 42.382...
# ..                                                ...
# 83  POLYGON ((-71.09013 42.37158, -71.09066 42.370...
# 84  POLYGON ((-71.10541 42.36641, -71.10570 42.366...
# 85  POLYGON ((-71.07157 42.36723, -71.07145 42.367...
# 86  POLYGON ((-71.12407 42.38421, -71.12414 42.384...
# 87  POLYGON ((-71.09180 42.36632, -71.09124 42.365...
#
#                            home_bgrp  count
# 0      2 (Tract 3546, Middlesex, MA)    860
# 1      1 (Tract 3533, Middlesex, MA)   1052
# 2      1 (Tract 3550, Middlesex, MA)    986
# 3      5 (Tract 3536, Middlesex, MA)   1974
# 4      2 (Tract 3544, Middlesex, MA)   1010
# ..                               ...    ...
# 83     1 (Tract 3526, Middlesex, MA)   1059
# 84     1 (Tract 3530, Middlesex, MA)     20
# 85  1 (Tract 3521.02, Middlesex, MA)   1785
# 86     2 (Tract 3540, Middlesex, MA)   2108
# 87     1 (Tract 3524, Middlesex, MA)    310
#
# [88 rows x 6 columns]

# %%
merged_data.plot(column='count', legend=True)
# Out:
# <AxesSubplot:>

# %%
bgrp_id = ['250173521021','250173523001','250173523002','250173524001','250173524002','250173526001','250173531012','250173531022']
analysis_area = merged_data[merged_data['id'].isin(bgrp_id)]
analysis_area
# Out:
#               id label                              name  \
# 23  250173524002  bgrp     2 (Tract 3524, Middlesex, MA)
# 31  250173523001  bgrp     1 (Tract 3523, Middlesex, MA)
# 41  250173531012  bgrp  2 (Tract 3531.01, Middlesex, MA)
# 66  250173531022  bgrp  2 (Tract 3531.02, Middlesex, MA)
# 79  250173523002  bgrp     2 (Tract 3523, Middlesex, MA)
# 83  250173526001  bgrp     1 (Tract 3526, Middlesex, MA)
# 85  250173521021  bgrp  1 (Tract 3521.02, Middlesex, MA)
# 87  250173524001  bgrp     1 (Tract 3524, Middlesex, MA)
#
#                                              geometry  \
# 23  POLYGON ((-71.08254 42.36324, -71.08378 42.363...
# 31  POLYGON ((-71.08923 42.36554, -71.08677 42.364...
# 41  POLYGON ((-71.10117 42.36390, -71.10087 42.363...
# 66  POLYGON ((-71.08821 42.36261, -71.08891 42.362...
# 79  POLYGON ((-71.07806 42.36591, -71.07791 42.366...
# 83  POLYGON ((-71.09013 42.37158, -71.09066 42.370...
# 85  POLYGON ((-71.07157 42.36723, -71.07145 42.367...
# 87  POLYGON ((-71.09180 42.36632, -71.09124 42.365...
#
#                            home_bgrp  count
# 23     2 (Tract 3524, Middlesex, MA)   2435
# 31     1 (Tract 3523, Middlesex, MA)   1915
# 41  2 (Tract 3531.01, Middlesex, MA)    956
# 66  2 (Tract 3531.02, Middlesex, MA)    854
# 79     2 (Tract 3523, Middlesex, MA)   2544
# 83     1 (Tract 3526, Middlesex, MA)   1059
# 85  1 (Tract 3521.02, Middlesex, MA)   1785
# 87     1 (Tract 3524, Middlesex, MA)    310

# %%
res_num = analysis_area['count'].sum()
res_num
# Out:
# 11858

# %%
work = pd.read_csv('/Users/majue/Documents/MIT/multi_stakeholders_indicator_d3-1/backend/data/replica-workforce_dataset.csv')
work.head()
# Out:
#               person_id          household_id  age     sex  \
# 0  12806380493944754724  15989382197808166668   50    male
# 1  17904240322270692150   9488703958750988728   51  female
# 2   4883733951303108711   5836213770753880991   20    male
# 3  13595548637453668386   4862965933270668524   30  female
# 4   7251370034833445643  14322534064787053660   38    male
#
#                  race_ethnicity   employment_status  \
# 0  white_not_hispanic_or_latino            employed
# 1  white_not_hispanic_or_latino            employed
# 2  black_not_hispanic_or_latino            employed
# 3  white_not_hispanic_or_latino  not_in_labor_force
# 4  white_not_hispanic_or_latino            employed
#
#                                       wfh  individual_income  \
# 0                               in_person              21927
# 1                               in_person              61019
# 2                               in_person               8239
# 3  unemployed_under_16_not_in_labor_force                  0
# 4                               in_person              67057
#
#         commute_mode  household_size  ...  available_vehicles resident_type  \
# 0       private_auto               5  ...          three_plus          core
# 1       private_auto               4  ...                 one          core
# 2       private_auto               3  ...          three_plus          core
# 3  other_travel_mode               3  ...          three_plus          core
# 4            walking               5  ...                zero          core
#
#                           home_bgrp                home_trct  \
# 0    1 (Tract 9705, Bennington, VT)    9705 (Bennington, VT)
# 1    1 (Tract 9705, Bennington, VT)    9705 (Bennington, VT)
# 2  1 (Tract 3011.02, Middlesex, MA)  3011.02 (Middlesex, MA)
# 3  3 (Tract 3011.02, Middlesex, MA)  3011.02 (Middlesex, MA)
# 4  3 (Tract 3271.02, Middlesex, MA)  3271.02 (Middlesex, MA)
#
#                 home_cty        home_st                      work_bgrp  \
# 0  Bennington County, VT        Vermont  2 (Tract 3523, Middlesex, MA)
# 1  Bennington County, VT        Vermont  2 (Tract 3523, Middlesex, MA)
# 2   Middlesex County, MA  Massachusetts  2 (Tract 3524, Middlesex, MA)
# 3   Middlesex County, MA  Massachusetts  5 (Tract 3536, Middlesex, MA)
# 4   Middlesex County, MA  Massachusetts  2 (Tract 3524, Middlesex, MA)
#
#               work_trct              work_cty        work_st
# 0  3523 (Middlesex, MA)  Middlesex County, MA  Massachusetts
# 1  3523 (Middlesex, MA)  Middlesex County, MA  Massachusetts
# 2  3524 (Middlesex, MA)  Middlesex County, MA  Massachusetts
# 3  3536 (Middlesex, MA)  Middlesex County, MA  Massachusetts
# 4  3524 (Middlesex, MA)  Middlesex County, MA  Massachusetts
#
# [5 rows x 21 columns]

# %%
# 统计人口数据，bgrp level
# 根据 'home_trct' 分组并计算每个地块的人数
work_count = work.groupby('work_bgrp').size().reset_index(name='count')
# 合并 'bgrp' DataFrame 和 'people_count' DataFrame，根据 'home_trct' 进行匹配
merged_data = bgrp.merge(work_count, left_on='name', right_on='work_bgrp', how='left')

# 打印合并结果
merged_data
# Out:
#               id label                              name  \
# 0   250173546002  bgrp     2 (Tract 3546, Middlesex, MA)
# 1   250173533001  bgrp     1 (Tract 3533, Middlesex, MA)
# 2   250173550001  bgrp     1 (Tract 3550, Middlesex, MA)
# 3   250173536005  bgrp     5 (Tract 3536, Middlesex, MA)
# 4   250173544002  bgrp     2 (Tract 3544, Middlesex, MA)
# ..           ...   ...                               ...
# 83  250173526001  bgrp     1 (Tract 3526, Middlesex, MA)
# 84  250173530001  bgrp     1 (Tract 3530, Middlesex, MA)
# 85  250173521021  bgrp  1 (Tract 3521.02, Middlesex, MA)
# 86  250173540002  bgrp     2 (Tract 3540, Middlesex, MA)
# 87  250173524001  bgrp     1 (Tract 3524, Middlesex, MA)
#
#                                              geometry  \
# 0   POLYGON ((-71.13286 42.38328, -71.13195 42.382...
# 1   POLYGON ((-71.10574 42.36182, -71.10556 42.361...
# 2   POLYGON ((-71.14066 42.39884, -71.14068 42.398...
# 3   POLYGON ((-71.11954 42.37631, -71.11948 42.376...
# 4   POLYGON ((-71.13697 42.38295, -71.13707 42.382...
# ..                                                ...
# 83  POLYGON ((-71.09013 42.37158, -71.09066 42.370...
# 84  POLYGON ((-71.10541 42.36641, -71.10570 42.366...
# 85  POLYGON ((-71.07157 42.36723, -71.07145 42.367...
# 86  POLYGON ((-71.12407 42.38421, -71.12414 42.384...
# 87  POLYGON ((-71.09180 42.36632, -71.09124 42.365...
#
#                            work_bgrp  count
# 0      2 (Tract 3546, Middlesex, MA)    232
# 1      1 (Tract 3533, Middlesex, MA)    578
# 2      1 (Tract 3550, Middlesex, MA)    874
# 3      5 (Tract 3536, Middlesex, MA)  11184
# 4      2 (Tract 3544, Middlesex, MA)    198
# ..                               ...    ...
# 83     1 (Tract 3526, Middlesex, MA)    125
# 84     1 (Tract 3530, Middlesex, MA)    316
# 85  1 (Tract 3521.02, Middlesex, MA)   6480
# 86     2 (Tract 3540, Middlesex, MA)    601
# 87     1 (Tract 3524, Middlesex, MA)   1539
#
# [88 rows x 6 columns]

# %%
analysis_area = merged_data[merged_data['id'].isin(bgrp_id)]
work_num = analysis_area['count'].sum()
work_num
# Out:
# 54293
